# %% [markdown]
# ## Package download

# %%
pip install streamlit
# Out:
# ...
#   Using cached streamlit-1.10.0-py2.py3-none-any.whl (9.1 MB)
# ...
#   Using cached rich-12.4.4-py3-none-any.whl (232 kB)
# ...
#   Using cached altair-4.2.0-py3-none-any.whl (812 kB)
# ...
#   Using cached tzlocal-4.2-py3-none-any.whl (19 kB)
# ...
#   Using cached blinker-1.4.tar.gz (111 kB)
# ...
#   Using cached pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
# ...
#   Using cached semver-2.13.0-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached Pympler-1.0.1-py3-none-any.whl (164 kB)
# ...
#   Using cached validators-0.20.0.tar.gz (30 kB)
# ...
#   Using cached commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
# ...
#   Using cached tzdata-2022.1-py2.py3-none-any.whl (339 kB)
# ...
#   Using cached pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# ...
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13478 sha256=6970a25ef46777a23f549b054709f756384c27bdbc5917e02c6d18043167d4e7
#   Stored in directory: c:\users\cobra\appdata\local\pip\cache\wheels\50\93\f8\4f0a42a03a06626d675f13907b6982ad5ecff383530af5a900
# ...

# %%
import pandas as pd
import numpy as np
from model import DataPreprocessor, ModelManager
import time
import geopandas as gpd
import pandas as pd

import geopandas

# %%
town_shp = gpd.read_file('mapdata202203151020/TOWN_MOI_1100415.shp', encoding='utf-8')

# %%
town_shp['COUNTYNAME'].unique()
# Out:
# array(['臺東縣', '屏東縣', '雲林縣', '彰化縣', '苗栗縣', '新竹縣', '嘉義縣', '高雄市', '宜蘭縣',
#        '連江縣', '金門縣', '臺中市', '澎湖縣', '南投縣', '花蓮縣', '基隆市', '臺北市', '新北市',
#        '臺南市', '桃園市', '嘉義市', '新竹市'], dtype=object)

# %%
from model import DataPreprocessor, ModelManager

# %%
# 將使用者輸入資料，轉成模型所需資料
class DataPreprocessor():
    def __init__(self):

        self.place_df = self.load_csv('csv/place_id.csv')
        self.gdf = gpd.read_file('mapdata202203151020/TOWN_MOI_1100415.shp', encoding='utf-8')
        self.gdf['place'] = self.gdf['COUNTYNAME'] + self.gdf['TOWNNAME']
        self.gdf = pd.merge(self.gdf, self.place_df, on ="place")

    # @st.cache # 建立快取
    def load_csv(self, file_path):
        print("DataPreprocessor load csv:" + file_path)
        return pd.read_csv(file_path)

    def get_place_id(self, palce):
        return self.place_df[self.place_df['place'] == palce].reset_index()['place_id'][0]

    def get_place_list(self):
        return self.place_df['place']
    
    def get_gdf(self):
        return self.gdf
    
    def get_economy_indicators(self, date):
        print(date)

# %%
dp = DataPreprocessor()
dp.get_gdf()
# Out:
# DataPreprocessor load csv:csv/place_id.csv
#     TOWNID  TOWNCODE COUNTYNAME TOWNNAME             TOWNENG COUNTYID  \
# 0      V02  10014020        臺東縣      成功鎮  Chenggong Township        V
# 1      T21  10013210        屏東縣      佳冬鄉    Jiadong Township        T
# 2      P13  10009130        雲林縣      麥寮鄉    Mailiao Township        P
# 3      V11  10014110        臺東縣      綠島鄉      Ludao Township        V
# 4      V16  10014160        臺東縣      蘭嶼鄉      Lanyu Township        V
# ..     ...       ...        ...      ...                 ...      ...
# 358    B27  66000270        臺中市      太平區    Taiping District        B
# 359    U12  10015120        花蓮縣      萬榮鄉    Wanrong Township        U
# 360    U07  10015020        花蓮縣      鳳林鎮    Fenglin Township        U
# 361    H10  68000100        桃園市      平鎮區   Pingzhen District        H
# 362    H09  68000090        桃園市      龍潭區    Longtan District        H
#
#     COUNTYCODE                                           geometry   place  \
# ...

# %%
pd.merge(town_shp, place_df, on ="place")
# Out:
#     TOWNID  TOWNCODE COUNTYNAME TOWNNAME             TOWNENG COUNTYID  \
# 0      V02  10014020        臺東縣      成功鎮  Chenggong Township        V
# 1      T21  10013210        屏東縣      佳冬鄉    Jiadong Township        T
# 2      P13  10009130        雲林縣      麥寮鄉    Mailiao Township        P
# 3      V11  10014110        臺東縣      綠島鄉      Ludao Township        V
# 4      V16  10014160        臺東縣      蘭嶼鄉      Lanyu Township        V
# ..     ...       ...        ...      ...                 ...      ...
# 358    B27  66000270        臺中市      太平區    Taiping District        B
# 359    U12  10015120        花蓮縣      萬榮鄉    Wanrong Township        U
# 360    U07  10015020        花蓮縣      鳳林鎮    Fenglin Township        U
# 361    H10  68000100        桃園市      平鎮區   Pingzhen District        H
# 362    H09  68000090        桃園市      龍潭區    Longtan District        H
#
#     COUNTYCODE                                           geometry   place  \
# ...

# %%
town_shp = gpd.read_file('mapdata202203151020/TOWN_MOI_1100415.shp', encoding='utf-8')

town_shp['place'] = town_shp['COUNTYNAME'] + town_shp['TOWNNAME']

# %%
town_shp['place'].unique()
# Out:
# array(['臺東縣成功鎮', '屏東縣佳冬鄉', '雲林縣麥寮鄉', '臺東縣綠島鄉', '臺東縣蘭嶼鄉', '彰化縣田中鎮',
#        '彰化縣社頭鄉', '屏東縣竹田鄉', '屏東縣萬丹鄉', '苗栗縣三灣鄉', '新竹縣峨眉鄉', '苗栗縣南庄鄉',
#        '嘉義縣太保市', '嘉義縣中埔鄉', '嘉義縣番路鄉', '嘉義縣水上鄉', '彰化縣員林市', '高雄市小港區',
#        '宜蘭縣蘇澳鎮', '宜蘭縣五結鄉', '宜蘭縣宜蘭市', '宜蘭縣壯圍鄉', '連江縣南竿鄉', '連江縣莒光鄉',
#        '金門縣金寧鄉', '金門縣烏坵鄉', '宜蘭縣羅東鎮', '宜蘭縣員山鄉', '宜蘭縣冬山鄉', '宜蘭縣三星鄉',
#        '宜蘭縣大同鄉', '新竹縣竹東鎮', '新竹縣新埔鎮', '新竹縣關西鎮', '新竹縣湖口鄉', '新竹縣芎林鄉',
#        '新竹縣橫山鄉', '新竹縣北埔鄉', '新竹縣尖石鄉', '新竹縣五峰鄉', '臺中市龍井區', '臺中市大雅區',
#        '臺中市沙鹿區', '臺中市梧棲區', '澎湖縣湖西鄉', '苗栗縣苗栗市', '苗栗縣卓蘭鎮', '苗栗縣大湖鄉',
#        '苗栗縣公館鄉', '苗栗縣銅鑼鄉', '苗栗縣頭屋鄉', '苗栗縣三義鄉', '苗栗縣西湖鄉', '苗栗縣造橋鄉',
#        '苗栗縣獅潭鄉', '苗栗縣泰安鄉', '彰化縣彰化市', '彰化縣和美鎮', '彰化縣線西鄉', '彰化縣伸港鄉',
#        '彰化縣秀水鄉', '彰化縣花壇鄉', '彰化縣芬園鄉', '彰化縣溪湖鎮', '嘉義縣東石鄉', '彰化縣大村鄉',
#        '彰化縣埔鹽鄉', '彰化縣埔心鄉', '彰化縣永靖鄉', '彰化縣二水鄉', '彰化縣二林鎮', '彰化縣埤頭鄉',
#        '彰化縣芳苑鄉', '彰化縣大城鄉', '彰化縣竹塘鄉', '彰化縣溪州鄉', '南投縣南投市', '南投縣埔里鎮',
#        '南投縣草屯鎮', '南投縣竹山鎮', '南投縣集集鎮', '南投縣名間鄉', '南投縣鹿谷鄉', '南投縣中寮鄉',
# ...
